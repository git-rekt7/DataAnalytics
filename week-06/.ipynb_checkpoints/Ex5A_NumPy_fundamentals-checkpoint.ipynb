# %% [markdown]
# # Ex5A NumPy Fundamentals
# ## Does what it says on the tin.
# ### High performance mathematical operations suited for data science

# %%
import numpy as np

# %% [markdown]
# ## Array Basics

# %%
fruits = ["apple", "banana", "cherry", "data"]

# %%
arr_1 = fruits # defines arr_1
print(arr_1)
# Out:
# ['apple', 'banana', 'cherry', 'data']

# %%
type(arr_1)
arr_1.dtype # This command didn't work for some reason, but it contains unicode string info
# arr_1 is defined as a list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 2
#       1 type(arr_1)
# ----> 2 arr_1.dtype # This command didn't work for some reason, but it contains unicode string info
#       3 # arr_1 is defined as a list
#
# AttributeError: 'list' object has no attribute 'dtype'

# %%
arr_2 = np.array([[10, 11, 12], # two dimensional array
                  [13, 14, 15]])

print(arr_2) # Prints array
# Out:
# [[10 11 12]
#  [13 14 15]]

# %%
print(arr_2.T) # the Transpose statement
# Out:
# [[10 13]
#  [11 14]
#  [12 15]]

# %%
print(arr_2) # first print statement to test if values are changed...They are not
# Out:
# [[10 11 12]
#  [13 14 15]]

# %%
arr_3 = np.array([[1, 3, 5], # Two dimensional array
                  [2, 4, 6]])

# %%
print(arr_3) # Typical array print statement
# Out:
# [[1 3 5]
#  [2 4 6]]

# %%
arr_4 = np.array([arr_3[0, 2], arr_3[1, 1]]) # Array quatro

# %%
print(arr_4) # print
# Out:
# [5 4]

# %%
arr_5 = np.ones((2, 2, 2), dtype=int) # three dimensional array

# %%
print(arr_5) # You know what this does
# Out:
# [[[1 1]
#   [1 1]]
#
#  [[1 1]
#   [1 1]]]
