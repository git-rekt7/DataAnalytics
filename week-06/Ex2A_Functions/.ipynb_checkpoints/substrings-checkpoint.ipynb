# %% [markdown]
# # Exercise 2.A Using Built in Functions
# ## Lab 1. Working with names - parsing strings

# %%
test_name = ("johnny dope")

# %%
def parse_and_display(name):
    for i in range (len(name)):
        if name [i] == ' ':
            first = name[:i]
            last = name[i+1:]
            print(f"Full name: {name}")
            print(f"First name: {first}")
            print(f"Last name: {last}")

# %%
parse_and_display(test_name)
# Out:
# Full name: johnny dope
# First name: johnny
# Last name: dope

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

# %% [raw]
# def parse_and_display('Corey Allen')

# %%
def parse_and_display2(name):
    parts = name.split()

    print(f"Full name: {name}")

    if len(parts) == 3:
        print(f"First name: {parts[0]}")
        print(f"Middle name: {parts[1]}")
        print(f"Last name: {parts[2]}")

# %%
NameList = ['Ten Ton Tammy', 'Maybe Mad Mandy', 'Too Tough Tony']

# %%
for name in NameList:
    parse_and_display2(name)
# Out:
# Full name: Ten Ton Tammy
# First name: Ten
# Middle name: Ton
# Last name: Tammy
# Full name: Maybe Mad Mandy
# First name: Maybe
# Middle name: Mad
# Last name: Mandy
# Full name: Too Tough Tony
# First name: Too
# Middle name: Tough
# Last name: Tony
